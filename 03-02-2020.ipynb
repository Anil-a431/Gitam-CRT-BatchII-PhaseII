# %%
Input:-
2
App Test Working Good 
Output:-
TEST

You need Print second word in Upper Case

# %%
#include<stdio.h>
#include<stdlib.h>
#include<string.h>
int main(){
	int i,len,cnt=1,n;
	char x[100];
	scanf("%d",&n);
	fflush(stdin);
	scanf("%[^\n]s",x);
	len = strlen(x);
	for(i=0;i<len;i++){
		if(x[i]==32){
			cnt++;
		}
		if(cnt==n){
			if(x[i]>=65 && x[i]<=90){
				printf("%c",x[i]);
			}
			else if(x[i]>=97 && x[i]<=122){
				printf("%c",x[i]-32);
			}
		}
		if(cnt>n){
			break;
		}
	}
	return 0;
}

# %%
Input:-
App Test Working Good 
Output:-
APP Test WORKING Good

# %%
Input:-
AppTestWoringGooD
Output:-
ApPTEsTWOrInGGOoD

# %%
Input:-
ABCD AABBCCDD ABCDABCC
Output:-
!@@!!!@@@@
!@!!@@!!!@@@!!!!@@@@
!@@!!!@@@@!@@!!!@@@

# %%
#include<stdio.h>
#include<string.h>
int main()
{
	int i,len,k,j;
	char x[100],ch='!';
	scanf("%[^\n]s",x);
	len = strlen(x);
	for(i=0;i<len;i++){
		if(x[i]!=32){
			k = x[i]-64;
			for(j=0;j<k;j++){
				printf("%c",ch);
			}
			if(ch=='!'){
				ch = '@';
			}
			else{
				ch = '!';
			}
		}
		else{
			printf("\n");
			ch = '!';
		}
	}
	return 0;
}

# %%
Input:-(input string consists of only lower case characters)
abcdabcd abcdef abcdaabbcc
Output:-
!@@$$$!!!!@$$!!!@@@@
!@@$$$!!!!@@@@@$$$$$$
!@@$$$!!!!@$!!@@$$$!!!

# %%
#include<stdio.h>
#include<string.h>
int main()
{
	int i,len,k,j;
	char x[100],ch='!';
	scanf("%[^\n]s",x);
	len = strlen(x);
	for(i=0;i<len;i++){
		if(x[i]!=32){
			k = x[i]-96;
			for(j=0;j<k;j++){
				printf("%c",ch);
			}
			if(ch=='!'){
				ch = '@';
			}
			else if(ch=='@'){
				ch = '$';
			}
			else{
				ch = '!';
			}
		}
		else{
			printf("\n");
			ch = '!';
		}
	}
	return 0;
}

# %%
Input:-
Ap12p19c313at91tion

Output:-
313

# %%
#include<stdio.h>
#include<string.h>
int main()
{
	int i,len,currSum=0,prevSum=0;
	char x[100];
	scanf("%s",x);
	len = strlen(x);
	for(i=0;i<len;i++){
		while(1){
			if(x[i]>=48 && x[i]<=57){
				currSum = currSum*10+(x[i]-48);
			}
			else{
				break;
			}
			i++;
		}
		if(prevSum<currSum){
			prevSum = currSum;
		}
		currSum = 0;
	}
	printf("%d",prevSum);
	return 0;
}

# %%
Structures in C Programming:-
=============================
Why Structures?
	This also user defined datatype
	If there is different type data is present
	You need to store some details like int,char,float,double

Need Structures?
	For example : Students, Products and .....

Define a structures
	Use struct Keyword to define the structure
	
	struct <strctName>{
		Datatype Member;
		Datatype Member;
		................
	};

	** Struct Define will not have memory
	
	** Struct takes the memory when object / variable is created.
	
How to create the struct variable or object:-
	1. Along with struct Defination
	struct <strctName>{
		Datatype Member;
		Datatype Member;
		................
	}obj;
	
	2. By using struct tag
		struct StructName obj;

# %%
Pointers:-

# %%
#include<stdio.h>
int main(){
	int x,*ptr;
	x = 10;
	ptr = &x;
	printf("\n Value x = %d",x);
	printf("\n Address of x = %u",&x);
	printf("\n Value of Ptr = %d",*ptr);
	printf("\n Address of ptr = %u",&ptr);
	printf("\n Internal Storage = %u",ptr);
	return 0;
}

# %%
#include<stdio.h>
int main(){
	int x,*ptr;
	x = 10;
	ptr = &x;
	x += 100;
	printf("%d",*ptr);
	return 0;
}

# %%
#include<stdio.h>
void fun1(int x,int y){
	printf("\n initial values of x and y");
	printf("\n x = %d \t y = %d",x,y);
	x += 10;
	y += 10;
	printf("\n After Modification ");
	printf("\n x = %d \t y = %d",x,y);
}
int main(){
	int a,b;
	printf("\n Enter two values ");
	scanf("%d%d",&a,&b);
	printf("\n Values of a and b : ");
	printf("\n a = %d \t b = %d",a,b);
	fun1(a,b);
	printf("\n after the function call ");
	printf("\n a = %d \t b = %d",a,b);
	return 0;
}
// Actual Parameters -- a and b
// Formal Paramters  -- x and y
// In this call by value formal parameters
// will not reflect back to actual parameters

# %%
#include<stdio.h>
void fun1(int *x,int *y){
	printf("\n Initial values of x and y ");
	printf("\n x = %d \t y = %d",*x,*y);
	*x = *x + 1;
	*y = *y + 1;
	printf("\n After Modification");
	printf("\n x = %d \t y = %d",*x,*y);
}
int main(){
	int a,b;
	printf("\n Enter two values : ");
	scanf("%d%d",&a,&b);
	printf("\n Before Function Call ");
	printf("\n a = %d \t b = %d",a,b);
	fun1(&a,&b);
	printf("\n After the Function Call ");
	printf("\n a = %d \t b = %d",a,b);
	return 0;
}
//Formal Parameters are reflected back to actual parameters

# %%
#include<stdio.h>
int returnSum(int a){
	int sum = 0;
	while(a!=0){
		sum = sum + (a%10);
		a /= 10;
	}
	if(sum<=9){
		return sum;
	}
	else{
		returnSum(sum);//Self Calling - Function Recursion
	}
}
int main(){
	int x;
	scanf("%d",&x);
	printf("%d",returnSum(x));
	return 0;
}

# %%
#include<stdio.h>
#include<stdlib.h>
struct Demo{
	char name[100];
	int id;
	float marks;
};
int main(){
	struct Demo obj;
	printf("\n Enter the Name : ");
	scanf("%s",obj.name);
	fflush(stdin);
	printf("\n Enter the Id ");
	scanf("%d",&obj.id);	
	printf("\n Enter the Marks ");
	scanf("%f",&obj.marks);
	printf("\n ----------------- \n");
	printf("\n Id = %d Name = %s Marks = %.2f",obj.id,obj.name,obj.marks);
	return 0;
}

# %%
#include<stdio.h>
#include<stdlib.h>
struct Demo{
	char name[100];
	int id;
	float marks;
};
int main(){
	struct Demo obj[100];
	int n,i;
	scanf("%d",&n);
	for(i=0;i<n;i++){
		printf("\n Enter the Name : ");
		scanf("%s",obj[i].name);
		printf("\n Enter the Id : ");
		scanf("%d",&obj[i].id);
		printf("\n Enter the Marks : ");
		scanf("%f",&obj[i].marks);
	}
	
	printf("\n ----------------- \n");
	for(i=0;i<n;i++){
		printf("\n Id = %d Name = %s Marks = %.2f",obj[i].id,obj[i].name,obj[i].marks);	
	}
	
	return 0;
}
