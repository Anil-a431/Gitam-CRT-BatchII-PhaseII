# %%
Doubly Linked List Insertion - Sorted Order

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next,*Prev;
}*S,*L,*P,*C;

void insertNode(){
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	nn->Prev = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		if(nn->Data <= S->Data){
			nn->Next = S;
			S->Prev = nn;
			S = nn;
		}
		else if(nn->Data >= L->Data){
			L->Next = nn;
			nn->Prev = L;
			L = nn;
		}
		else{
			for(C=S;C->Data<=nn->Data;P=C,C=C->Next);
			nn->Next = C;
			nn->Prev = P;
			P->Next = nn;
			C->Prev = nn;
		}
		printf("\n New Node Inserted ... ");
	}
	getch();
}

void deleteNode(){
	getch();
}

void displayNodes(){
	int o;
	printf("\n  Display Doubly Linked List ");
	printf("\n  1. Fwd ");
	printf("\n  2. Rev ");
	printf("\n Enter Your Option : ");
	scanf("%d",&o);
	switch(o){
		case 1: for(C=S;C!=NULL;C=C->Next)
				{
					printf("%d ",C->Data);
					//printf("%u ",C->Next);
				}
		break;
		case 2: for(C=L;C!=NULL;C=C->Prev)
				{
					printf("%d ",C->Data);
					//printf("%u ",C->Prev);
				}
		break;
	}
	getch();
}


int main(){
	S = L = P = C = NULL;
	int x;
	while(1){
		system("cls");
		printf("\n Doubly Linked List");
		printf("\n 1. Insert");
		printf("\n 2. Delete");
		printf("\n 3. Display");
		printf("\n 4. Exit");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();
			break;
			case 3: displayNodes();
			break;
			case 4: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}i

# %%
Doubly Linked List - Avoid Duplicate Insertions
Link Nodes
10 20 30 40
Insert : 10
Output : Not Possible Insert
Insert : 22
Output : 10 20 22 30 40

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next,*Prev;
}*S,*L,*P,*C;

void insertNode(){
	int flag = 0;
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	nn->Prev = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		for(C=S;C!=NULL;C=C->Next){
			if(nn->Data == C->Data){
				printf("\n Not Possible to Insert");
				flag = 1;
				break;
			}
		}
		if(flag==0)
		{
			if(nn->Data <= S->Data){
			nn->Next = S;
			S->Prev = nn;
			S = nn;
		}
		else if(nn->Data >= L->Data){
			L->Next = nn;
			nn->Prev = L;
			L = nn;
		}
		else{
			for(C=S;C->Data<=nn->Data;P=C,C=C->Next);
			nn->Next = C;
			nn->Prev = P;
			P->Next = nn;
			C->Prev = nn;
		}
		printf("\n New Node Inserted ... ");
		}
		
	}
	getch();
}

void deleteNode(){
	getch();
}

void displayNodes(){
	int o;
	printf("\n  Display Doubly Linked List ");
	printf("\n  1. Fwd ");
	printf("\n  2. Rev ");
	printf("\n Enter Your Option : ");
	scanf("%d",&o);
	switch(o){
		case 1: for(C=S;C!=NULL;C=C->Next)
				{
					printf("%d ",C->Data);
					//printf("%u ",C->Next);
				}
		break;
		case 2: for(C=L;C!=NULL;C=C->Prev)
				{
					printf("%d ",C->Data);
					//printf("%u ",C->Prev);
				}
		break;
	}
	getch();
}


int main(){
	S = L = P = C = NULL;
	int x;
	while(1){
		system("cls");
		printf("\n Doubly Linked List");
		printf("\n 1. Insert");
		printf("\n 2. Delete");
		printf("\n 3. Display");
		printf("\n 4. Exit");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();
			break;
			case 3: displayNodes();
			break;
			case 4: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}

# %%
Link Nodes
10 10 20 20 30 40
Output:  10 20 30 (Alternate Nodes Printing)

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next,*Prev;
}*S,*L,*P,*C;

void insertNode(){
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	nn->Prev = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		if(nn->Data <= S->Data){
			nn->Next = S;
			S->Prev = nn;
			S = nn;
		}
		else if(nn->Data >= L->Data){
			L->Next = nn;
			nn->Prev = L;
			L = nn;
		}
		else{
			for(C=S;C->Data<=nn->Data;P=C,C=C->Next);
			nn->Next = C;
			nn->Prev = P;
			P->Next = nn;
			C->Prev = nn;
		}
		printf("\n New Node Inserted ... ");
	}
	getch();
}

void deleteNode(){
	getch();
}

void displayNodes(){
	int o;
	printf("\n  Display Doubly Linked List ");
	printf("\n  1. Fwd ");
	printf("\n  2. Rev ");
	printf("\n Enter Your Option : ");
	scanf("%d",&o);
	switch(o){
		case 1: for(C=S;C!=NULL;C=C->Next)
				{
					printf("%d ",C->Data);
					//printf("%u ",C->Next);
				}
		break;
		case 2: for(C=L;C!=NULL;C=C->Prev)
				{
					printf("%d ",C->Data);
					//printf("%u ",C->Prev);
				}
		break;
	}
	getch();
}
void alternateNodesPrint(){
	int a=1;
	for(C=S;C!=NULL;C=C->Next,a++){
		if(a%2!=0)
		{
			printf("%d ",C->Data);	
		}		
	}
	getch();
}

int main(){
	S = L = P = C = NULL;
	int x;
	while(1){
		system("cls");
		printf("\n Doubly Linked List");
		printf("\n 1. Insert");
		printf("\n 2. Delete");
		printf("\n 3. Display");
		printf("\n 4. Display Alternate Nodes");
		printf("\n 5. Exit");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();
			break;
			case 3: displayNodes();
			break;
			case 4 : alternateNodesPrint();
			break;
			case 5: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}

# %%
Delete Node at start of Doubly Linked List

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next,*Prev;
}*S,*L,*P,*C;

void insertNode(){
	int flag = 0;
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	nn->Prev = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		for(C=S;C!=NULL;C=C->Next){
			if(nn->Data == C->Data){
				printf("\n Not Possible to Insert");
				flag = 1;
				break;
			}
		}
		if(flag==0)
		{
			if(nn->Data <= S->Data){
			nn->Next = S;
			S->Prev = nn;
			S = nn;
	 		}
			else if(nn->Data >= L->Data){
			L->Next = nn;
			nn->Prev = L;
			L = nn;
			}
			else{
			for(C=S;C->Data<=nn->Data;P=C,C=C->Next);
			nn->Next = C;
			nn->Prev = P;
			P->Next = nn;
			C->Prev = nn;
			}
			printf("\n New Node Inserted ... ");
		}
		
	}
	getch();
}

void deleteNode(){
	if(S==NULL){
		printf("\n Doubly Linked List Empty");
	}
	else{
		if(S->Next==NULL){
			S = L = NULL;
		}
		else{
			C = S;
			S = S->Next;
			C->Next = NULL;
			S->Prev = NULL;
			C = NULL;
		}
		printf("\n Node is Deleted...");
	}
	getch();
}

void displayNodes(){
	int o;
	printf("\n  Display Doubly Linked List ");
	printf("\n  1. Fwd ");
	printf("\n  2. Rev ");
	printf("\n Enter Your Option : ");
	scanf("%d",&o);
	switch(o){
		case 1: for(C=S;C!=NULL;C=C->Next)
				{
					printf("%d ",C->Data);
					//printf("%u ",C->Next);
				}
		break;
		case 2: for(C=L;C!=NULL;C=C->Prev)
				{
					printf("%d ",C->Data);
					//printf("%u ",C->Prev);
				}
		break;
	}
	getch();
}


int main(){
	S = L = P = C = NULL;
	int x;
	while(1){
		system("cls");
		printf("\n Doubly Linked List");
		printf("\n 1. Insert");
		printf("\n 2. Delete");
		printf("\n 3. Display");
		printf("\n 4. Exit");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();
			break;
			case 3: displayNodes();
			break;
			case 4: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}

# %%
Delete Node at the end of Doubly Linked List

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next,*Prev;
}*S,*L,*P,*C;

void insertNode(){
	int flag = 0;
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	nn->Prev = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		for(C=S;C!=NULL;C=C->Next){
			if(nn->Data == C->Data){
				printf("\n Not Possible to Insert");
				flag = 1;
				break;
			}
		}
		if(flag==0)
		{
			if(nn->Data <= S->Data){
			nn->Next = S;
			S->Prev = nn;
			S = nn;
	 		}
			else if(nn->Data >= L->Data){
			L->Next = nn;
			nn->Prev = L;
			L = nn;
			}
			else{
			for(C=S;C->Data<=nn->Data;P=C,C=C->Next);
			nn->Next = C;
			nn->Prev = P;
			P->Next = nn;
			C->Prev = nn;
			}
			printf("\n New Node Inserted ... ");
		}
		
	}
	getch();
}

void deleteNode(){
	if(S==NULL){
		printf("\n Doubly Linked List Empty");
	}
	else if(S->Next==NULL){
		S = L = NULL;
	}
	else{
		P = L->Prev;
		C = L;
		L = P;
		P->Next = NULL;
		C->Prev = NULL;
		C = P = NULL;
	}
	getch();
}

void displayNodes(){
	int o;
	printf("\n  Display Doubly Linked List ");
	printf("\n  1. Fwd ");
	printf("\n  2. Rev ");
	printf("\n Enter Your Option : ");
	scanf("%d",&o);
	switch(o){
		case 1: for(C=S;C!=NULL;C=C->Next)
				{
					printf("%d ",C->Data);
					//printf("%u ",C->Next);
				}
		break;
		case 2: for(C=L;C!=NULL;C=C->Prev)
				{
					printf("%d ",C->Data);
					//printf("%u ",C->Prev);
				}
		break;
	}
	getch();
}


int main(){
	S = L = P = C = NULL;
	int x;
	while(1){
		system("cls");
		printf("\n Doubly Linked List");
		printf("\n 1. Insert");
		printf("\n 2. Delete");
		printf("\n 3. Display");
		printf("\n 4. Exit");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();
			break;
			case 3: displayNodes();
			break;
			case 4: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}

# %%
Delete a Node from Doubly Linked List - From any Position

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next,*Prev;
}*S,*L,*P,*C;

void insertNode(){
	int flag = 0;
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	nn->Prev = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		for(C=S;C!=NULL;C=C->Next){
			if(nn->Data == C->Data){
				printf("\n Not Possible to Insert");
				flag = 1;
				break;
			}
		}
		if(flag==0)
		{
			if(nn->Data <= S->Data){
			nn->Next = S;
			S->Prev = nn;
			S = nn;
	 		}
			else if(nn->Data >= L->Data){
			L->Next = nn;
			nn->Prev = L;
			L = nn;
			}
			else{
			for(C=S;C->Data<=nn->Data;P=C,C=C->Next);
			nn->Next = C;
			nn->Prev = P;
			P->Next = nn;
			C->Prev = nn;
			}
			printf("\n New Node Inserted ... ");
		}
		
	}
	getch();
}

void deleteNode(){
	int n;
	if(S==NULL){
		printf("\n Doubly Linked List Empty");
	}
	else{
		printf("\n Enter the Value : ");
		scanf("%d",&n);
		if(S->Next == NULL && S->Data == n){
			S = L = NULL;
		}
		else if(S->Data == n){
			C = S;
			S = S->Next;
			C->Next = NULL;
			C = NULL;
		}
		else if(L->Data == n){
			P = L->Next;
			C = L;
			L = P;
			P->Next = NULL;
			C->Prev = NULL;
			C = P = NULL;
		}
		else{
			for(C=S;C->Data != n && C!=NULL;P=C,C=C->Next);
			if(C==NULL){
				printf("\n Node is not found");
			}
			else{
				P->Next = C->Next;
				C->Next->Prev = P;
				C->Next = NULL;
				C->Prev = NULL;
				C = NULL;
			}
			
		}
	}
	getch();
}

void displayNodes(){
	int o;
	printf("\n  Display Doubly Linked List ");
	printf("\n  1. Fwd ");
	printf("\n  2. Rev ");
	printf("\n Enter Your Option : ");
	scanf("%d",&o);
	switch(o){
		case 1: for(C=S;C!=NULL;C=C->Next)
				{
					printf("%d ",C->Data);
					//printf("%u ",C->Next);
				}
		break;
		case 2: for(C=L;C!=NULL;C=C->Prev)
				{
					printf("%d ",C->Data);
					//printf("%u ",C->Prev);
				}
		break;
	}
	getch();
}


int main(){
	S = L = P = C = NULL;
	int x;
	while(1){
		system("cls");
		printf("\n Doubly Linked List");
		printf("\n 1. Insert");
		printf("\n 2. Delete");
		printf("\n 3. Display");
		printf("\n 4. Exit");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();
			break;
			case 3: displayNodes();
			break;
			case 4: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}

# %%
Delete from Particular Position in Doubly Linked List

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next,*Prev;
}*S,*L,*P,*C;

void insertNode(){
	int flag = 0;
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	nn->Prev = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		for(C=S;C!=NULL;C=C->Next){
			if(nn->Data == C->Data){
				printf("\n Not Possible to Insert");
				flag = 1;
				break;
			}
		}
		if(flag==0)
		{
			if(nn->Data <= S->Data){
			nn->Next = S;
			S->Prev = nn;
			S = nn;
	 		}
			else if(nn->Data >= L->Data){
			L->Next = nn;
			nn->Prev = L;
			L = nn;
			}
			else{
			for(C=S;C->Data<=nn->Data;P=C,C=C->Next);
			nn->Next = C;
			nn->Prev = P;
			P->Next = nn;
			C->Prev = nn;
			}
			printf("\n New Node Inserted ... ");
		}
		
	}
	getch();
}

void deleteNode(){
	int pos,cnt=1,i=1;
	if(S==NULL){
		printf("\n Doubly Linked List Empty");
	}
	else{
		printf("\n Enter the Position : ");
		scanf("%d",&pos);
		for(C=S;C!=NULL;C=C->Next,cnt++);
		if(pos>cnt){
			printf("\n Invalid Position");
		}
		else{
			for(C=S;i<pos;P=C,C=C->Next,i++);
			P->Next = C->Next;
				C->Next->Prev = P;
				C->Next = NULL;
				C->Prev = NULL;
				C = NULL;
		}
	}
	getch();
}

void displayNodes(){
	int o;
	printf("\n  Display Doubly Linked List ");
	printf("\n  1. Fwd ");
	printf("\n  2. Rev ");
	printf("\n Enter Your Option : ");
	scanf("%d",&o);
	switch(o){
		case 1: for(C=S;C!=NULL;C=C->Next)
				{
					printf("%d ",C->Data);
					//printf("%u ",C->Next);
				}
		break;
		case 2: for(C=L;C!=NULL;C=C->Prev)
				{
					printf("%d ",C->Data);
					//printf("%u ",C->Prev);
				}
		break;
	}
	getch();
}


int main(){
	S = L = P = C = NULL;
	int x;
	while(1){
		system("cls");
		printf("\n Doubly Linked List");
		printf("\n 1. Insert");
		printf("\n 2. Delete");
		printf("\n 3. Display");
		printf("\n 4. Exit");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();
			break;
			case 3: displayNodes();
			break;
			case 4: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}

# %%
Delete the repeated nodes in Doubly linked list
Link Nodes
10 10 20 20 30 40
Input : 10 (Node Value)
Output : 20 20 30 40
